# %% [markdown]
# # First import python libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-532c1982-5c10-41dc-820f-80f4a9751e96" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-532c1982-5c10-41dc-820f-80f4a9751e96">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv('EastWestAirlines.csv')
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.head()
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
# 3    4    14776           0          1          1          1          500
# 4    5    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1

# %%
df.drop('ID#',axis=1,inplace=True)
df
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # **Data Preprocessing:**

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from scipy import stats

# %% [markdown]
# # Preprocess the dataset to handle missing values, remove outliers, and scale the features if necessary.

# %%
df.isnull().sum()
# Out:
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
# Handling missing values
imputer = SimpleImputer(strategy='mean')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# %%
df_imputed
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     28143.0         0.0        1.0        1.0        1.0        174.0
# 1     19244.0         0.0        1.0        1.0        1.0        215.0
# 2     41354.0         0.0        1.0        1.0        1.0       4123.0
# 3     14776.0         0.0        1.0        1.0        1.0        500.0
# 4     97752.0         0.0        4.0        1.0        1.0      43300.0
# ...       ...         ...        ...        ...        ...          ...
# 3994  18476.0         0.0        1.0        1.0        1.0       8525.0
# 3995  64385.0         0.0        1.0        1.0        1.0        981.0
# 3996  73597.0         0.0        3.0        1.0        1.0      25447.0
# 3997  54899.0         0.0        1.0        1.0        1.0        500.0
# 3998   3016.0         0.0        1.0        1.0        1.0          0.0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Removing outliers using Z-score (optional)
df_cleaned = df_imputed[(np.abs(stats.zscore(df_imputed)) < 3).all(axis=1)]

# %%
df_cleaned
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     28143.0         0.0        1.0        1.0        1.0        174.0
# 1     19244.0         0.0        1.0        1.0        1.0        215.0
# 2     41354.0         0.0        1.0        1.0        1.0       4123.0
# 3     14776.0         0.0        1.0        1.0        1.0        500.0
# 4     97752.0         0.0        4.0        1.0        1.0      43300.0
# ...       ...         ...        ...        ...        ...          ...
# 3994  18476.0         0.0        1.0        1.0        1.0       8525.0
# 3995  64385.0         0.0        1.0        1.0        1.0        981.0
# 3996  73597.0         0.0        3.0        1.0        1.0      25447.0
# 3997  54899.0         0.0        1.0        1.0        1.0        500.0
# 3998   3016.0         0.0        1.0        1.0        1.0          0.0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
# Scaling features
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df_cleaned), columns=df_cleaned.columns)

# %%
df_scaled
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.523260   -0.158869  -0.755664        0.0        0.0    -0.779029
# 1    -0.667084   -0.158869  -0.755664        0.0        0.0    -0.776768
# 2    -0.309747   -0.158869  -0.755664        0.0        0.0    -0.561235
# 3    -0.739295   -0.158869  -0.755664        0.0        0.0    -0.761050
# 4     0.601746   -0.158869   1.517591        0.0        0.0     1.599448
# ...        ...         ...        ...        ...        ...          ...
# 3625 -0.679496   -0.158869  -0.755664        0.0        0.0    -0.318457
# 3626  0.062475   -0.158869  -0.755664        0.0        0.0    -0.734522
# 3627  0.211358   -0.158869   0.759839        0.0        0.0     0.614823
# 3628 -0.090836   -0.158869  -0.755664        0.0        0.0    -0.761050
# 3629 -0.929358   -0.158869  -0.755664        0.0        0.0    -0.788626
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# # Perform exploratory data analysis (EDA) to gain insights into the distribution of data and identify potential clusters.

# %%
#pairplot to visualize relationship
sns.pairplot(df_scaled)
plt.show()

# %%
# Heatmap to check correlation
plt.figure(figsize=(8,8))
sns.heatmap(df_scaled.corr(),annot=True,cmap='coolwarm')
plt.show()

# %% [markdown]
# # **Implementing Clustering Algorithms:**

# %% [markdown]
# # Implement the K-Means, hierarchical, and DBSCAN algorithms using a programming language such as Python with libraries like scikit-learn or MATLAB.

# %% [markdown]
# # K-Means Clustering

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Elbow method to find the optimal number of clusters

wcss=[]
km=range(1,10)
for k in km:
  kmeans=KMeans(n_clusters=k , random_state=42)
  kmeans.fit(df_scaled)
  wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ...

# %% [markdown]
# # Plotting the Elbow Curve

# %%
plt.figure(figsize=(8,8))
plt.plot(km,wcss,'b*-')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal kmeans')
plt.show()

# %% [markdown]
# # Apply K-Means with the optimal K

# %%
kmeans=KMeans(n_clusters=3 , random_state=42)
kmeans_labels=kmeans.fit_predict(df_scaled)
kmeans_labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([1, 1, 1, ..., 2, 1, 1], dtype=int32)

# %%
# Evaluate using the silhouette score
silhouette_kmeans = silhouette_score(df_scaled, kmeans_labels)
print('Silhouette Score :=',silhouette_kmeans)
# Out:
# Silhouette Score := 0.31914997508947546

# %% [markdown]
# # **Hierarchical Clustering**

# %% [markdown]
# # in Hierarchical clustering Agglomerative clustering are using

# %%
from sklearn.cluster import AgglomerativeClustering
import scipy.cluster.hierarchy as shc

# %% [markdown]
# # Plot Dendrogram

# %%
plt.figure(figsize=(10,7))
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(df_scaled, method='ward'))

# %% [markdown]
# # Apply Hierarchical clustering

# %%
hierarchical = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='ward')
hierarchical_labels = hierarchical.fit_predict(df_scaled)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:1006: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(

# %%
silhouette_hierarchical=silhouette_score(df_scaled,hierarchical_labels)
print('Silhouette Score :=',silhouette_hierarchical)
# Out:
# Silhouette Score := 0.28440398074016243

# %% [markdown]
# # **DBSCAN Clustering**

# %%
from sklearn.cluster import DBSCAN

# %% [markdown]
# # **Apply the DBSCAN**

# %%
dbscan=DBSCAN(eps=0.5, min_samples=5)
dbscan_labels=dbscan.fit_predict(df_scaled)

# %%
# Evaluate using silhouette score ( if cluster larger than 1)

if len(set(dbscan_labels))>1:
  silhouette_dbscan = silhouette_score(df_scaled,dbscan_labels)
  print('Silhouette dbscan :-',silhouette_dbscan)
else:
  print('DBSCAN did not form significant clusters.')
# Out:
# Silhouette dbscan :- -0.2868751166819865

# %%
print('Number of cluster :-',len(set(dbscan_labels)))
# Out:
# Number of cluster :- 23

# %% [markdown]
# # **Visualization of Clusters**

# %% [markdown]
# # Scatter plot for K-means cluster

# %%
plt.scatter(df_scaled.iloc[:,0],df_scaled.iloc[:,1],c=kmeans_labels,cmap='viridis')
plt.title('K-Means Cluster')
plt.show()

# %% [markdown]
# # Scatter plot for Hierarchical Clusters

# %%
plt.scatter(df_scaled.iloc[:, 0], df_scaled.iloc[:, 1], c=hierarchical_labels, cmap='viridis')
plt.title('Hierarchical Clusters')
plt.show()

# %% [markdown]
# # Scatter plot for DBSCAN Clusters

# %%
plt.scatter(df_scaled.iloc[:, 0], df_scaled.iloc[:, 1], c=dbscan_labels, cmap='viridis')
plt.title('DBSCAN Clusters')
plt.show()
